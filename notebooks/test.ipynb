# %%
players[players["name"]=="Kylian Mbappé"]
# Out:
#        player_id first_name last_name           name  last_season  \
# 18781     342229     Kylian    Mbappé  Kylian Mbappé         2024
#
#        current_club_id    player_code country_of_birth city_of_birth  \
# 18781              418  kylian-mbappe           France         Paris
#
#       country_of_citizenship        date_of_birth    sub_position position  \
# 18781                 France  1998-12-20 00:00:00  Centre-Forward   Attack
#
#         foot  height_in_cm contract_expiration_date agent_name  \
# 18781  right         178.0      2029-06-30 00:00:00       None
#
#                                                image_url  \
# 18781  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 18781  https://www.transfermarkt.co.uk/kylian-mbappe/...
#
#       current_club_domestic_competition_id           current_club_name  \
# 18781                                  ES1  Real Madrid Club de Fútbol
#
# ...

# %% [markdown]
# Idee: Differenz zwischen erster Marktwert und letzter, Zeitraum, Goal/Assist per game

# %%
player_valuations[player_valuations["player_id"]==342229]#.drop_duplicates(subset=['year'], keep='first')
# Out:
#         player_id        date  market_value_in_eur  current_club_id  \
# 155631     342229  2015-12-02                50000              418
# 161699     342229  2016-02-04               250000              418
# 167551     342229  2016-04-09              1000000              418
# 173911     342229  2016-07-13              1500000              418
# 184542     342229  2016-11-01              4000000              418
# 191865     342229  2017-01-16             10000000              418
# 202164     342229  2017-06-01             35000000              418
# 215581     342229  2017-10-12             90000000              418
# 227167     342229  2018-01-24            120000000              418
# 238252     342229  2018-06-04            120000000              418
# 246035     342229  2018-07-16            150000000              418
# 250072     342229  2018-10-24            180000000              418
# 253179     342229  2018-12-17            200000000              418
# ...

# %%
appearances[appearances["player_id"]==342229].head()
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 446991  2600612_342229  2600612     342229             162
# 451555  2618992_342229  2618992     342229             162
# 453653  2600632_342229  2600632     342229             162
# 469223  2609680_342229  2609680     342229             162
# 478885  2609720_342229  2609720     342229             162
#
#         player_current_club_id        date    player_name competition_id  \
# 446991                     418  2015-12-02  Kylian Mbappé            FR1
# 451555                     418  2015-12-10  Kylian Mbappé             EL
# 453653                     418  2015-12-13  Kylian Mbappé            FR1
# 469223                     418  2016-01-24  Kylian Mbappé            FR1
# 478885                     418  2016-02-14  Kylian Mbappé            FR1
#
#         yellow_cards  red_cards  goals  assists  minutes_played
# 446991             0          0      0        0               2
# ...

# %%
transfers[transfers["player_id"]==342229]
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 3734      342229    2024-07-01           24/25           583         418
# 46259     342229    2018-07-01           18/19           162         583
# 48275     342229    2018-06-30           17/18           583         162
# 50046     342229    2017-08-31           17/18           162         583
# 58812     342229    2016-01-01           15/16          9669         162
# 60829     342229    2015-07-01           15/16         45617        9669
# 67574     342229    2013-07-01           13/14         43658       45617
# 72175     342229    2011-07-01           11/12         83011       43658
#
#       from_club_name   to_club_name  transfer_fee  market_value_in_eur  \
# 3734        Paris SG    Real Madrid           0.0          180000000.0
# 46259         Monaco       Paris SG   180000000.0          120000000.0
# 48275       Paris SG         Monaco           0.0          120000000.0
# ...

# %%
combined_data_agg[combined_data_agg["name"]=="Kylian Mbappé"]
# Out:
#         player_id       date  market_value_in_eur_x  current_club_id_x  \
# 85391      342229 2015-12-02                  50000                418
# 89679      342229 2016-02-04                 250000                418
# 103415     342229 2017-01-16               10000000                418
# 122093     342229 2018-01-24              120000000                418
# 122094     342229 2018-01-24              120000000                418
# 143059     342229 2019-06-03              200000000                418
# 163503     342229 2020-04-08              180000000                418
# 180344     342229 2021-04-09              160000000                418
# 197465     342229 2022-05-30              160000000                418
# 224307     342229 2023-06-27              180000000                418
# 233032     342229 2024-06-03              180000000                418
#
#        player_club_domestic_competition_id  year first_name last_name  \
# ...

# %%
combined_data_hist[combined_data_hist["name"]=="Kylian Mbappé"]#.drop_duplicates()
# Out:
#         player_id       date  market_value_in_eur_x  current_club_id_x  \
# 28005      342229 2015-12-02                  50000                418
# 30615      342229 2016-02-04                 250000                418
# 37648      342229 2017-01-16               10000000                418
# 46627      342229 2018-01-24              120000000                418
# 46628      342229 2018-01-24              120000000                418
# 55760      342229 2019-06-03              200000000                418
# 66161      342229 2020-04-08              180000000                418
# 74175      342229 2021-04-09              160000000                418
# 81086      342229 2022-05-30              160000000                418
# 94726      342229 2023-06-27              180000000                418
# 100854     342229 2024-06-03              180000000                418
#
#        player_club_domestic_competition_id  year first_name last_name  \
# ...

# %%
combined_data[combined_data["name"]=="Kylian Mbappé"]
# Out:
#         player_id       date  market_value_in_eur_x  current_club_id_x  \
# 28005      342229 2015-12-02                  50000                418
# 30615      342229 2016-02-04                 250000                418
# 37648      342229 2017-01-16               10000000                418
# 46627      342229 2018-01-24              120000000                418
# 46628      342229 2018-01-24              120000000                418
# 55760      342229 2019-06-03              200000000                418
# 66161      342229 2020-04-08              180000000                418
# 74175      342229 2021-04-09              160000000                418
# 81086      342229 2022-05-30              160000000                418
# 94726      342229 2023-06-27              180000000                418
# 100854     342229 2024-06-03              180000000                418
#
#        player_club_domestic_competition_id  year first_name last_name  \
# ...

# %% [markdown]
# combined_data_filtered[combined_data_filtered["name"]=="Kylian Mbappé"]

# %%
fig = px.box(
    combined_data_agg_no_outliers, 
    y="current_market_value", 
    color=combined_data_agg_no_outliers['is_retired'].map({True: 'Retired', False: 'Active'}),
    title="Boxplot of Current Market Value, Divided by Active or Retired (2020) Player, Without Outliers",
    labels={"current_market_value": "Current Market Value (in M€)"},
    hover_data=["name", "age"],
)

fig.show()
